# %%
# Step 2: 
import matplotlib.pyplot as plt
daily_sales = [
    45000, 52000, 48000, 51000, 47000, 55000, 49000, 53000,59000, 46000, 50000, 
    54000, 48000,52000, 57000, 56000, 43000, 52000, 49000, 55000, 43500, 50000, 45000, 47000, 48100
]

# %%
# Step 3:
bins = [42000, 44000, 46000, 48000, 50000, 52000, 54000, 56000, 58000, 60000]
plt.hist(daily_sales, bins=bins, edgecolor = 'black')

plt.title("Nkwen Traders Daily Sales Distribution")

plt.xlabel("Daily Sales (FCFA)")
plt.ylabel("Number of Days")

plt.show()

# %%
# Step 4:

# %% [markdown]
# #1. Before reaching for a term like "normal" or "skewed," just describe what you literally see: where's the tallest bar? Is it roughly in the middle, or off to one side? Are there any gaps, or a second smaller cluster of bars separate from the main group?
#
# ### From what I see the tallest bar is around 48000 to 50000 FCFA and is near the middle of the distribution. The bars gradually becomes shorter on both sides. Ther are no obvious gaps, and ther is no seperat group of bars away from the main group.
#
# #2. Write this raw description down first, in your own words, before applying any statistical vocabulary.
#
# ### Most of the daily sales are around 48,000–55,000 FCFA. The highest number of days is around 48,000–50,000 FCFA, while there are fewer days with very low or very high sales. The bars form one main group.

# %%
# Step 5:

# %% [markdown]
# ### The histogram is roughly normal because it has one main peak near the middle, and the bars become shorter as we move away from the middle.
#
# ### It is not bimodal because there are not two clearly separate peaks with a large dip between them.

# %%
# Step 6:

# %% [markdown]
# # 1. Describing the shape
#
# ### Nkwen Traders’ daily sales are roughly normally distributed, with one main peak around 48,000–50,000 FCFA. The number of days becomes smaller as sales move farther away from this range.
#
# # 2. What does this tell us about daily sales?
#
# ### This tells us that most days have sales fairly close to a typical level. Very low and very high sales happen less often. This means Nkwen Traders ### can expect its daily sales to usually stay within a fairly predictable range.
#
# # 3. Is there a long tail?
# ### There is no very strong long tail on either side. The sales decrease fairly gradually toward both the lower and higher values.
#
# # 4. Is it bimodal?
# ### No. There are not two clearly separate groups of sales, so there is no strong evidence from this graph that Nkwen Traders has two different types ### of sales days.

# %%
# Step 7:

# %% [markdown]
# ### 1. Connect to mean and median
#
# ### Since the data is roughly normal, the mean and median are both useful for describing a typical sales day. The mean is about 50,184 FCFA, while the median is 50,000 FCFA, so they are very close.
#
# ### 2. Connect to standard deviation
#
# ###  A single standard deviation can give us a useful idea of how much the daily sales normally vary from the average Since, the data has one main group,. It does not appear that two separate groups are being mixed together.
